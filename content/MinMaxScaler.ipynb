# %% [markdown]
# * Mark
# * popdf = dataframe of World Population Dataset
# * climdf = dataframe of Climate Change Indicators Dataset
# * gdpdf = dataframe of World GDP Dataset

# %% [markdown]
# ## Importing necessary libraries

# %%
from sklearn import preprocessing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

popdf = pd.read_csv("C:/Users/Rauan/practice/data/World Population Dataset.csv")
climdf = pd.read_csv(r'C:/Users/Rauan/practice/data/climate_change_indicators.csv')
gdpdf = pd.read_csv(r'C:/Users/Rauan/practice/data/world_gdp_data.csv', encoding='cp1252')

# %% [markdown]
# ## World Population

# %% [markdown]
# ### Scaling Columns in World Population, using MinMaxScaler, correlation matrix

# %%
columns_scale = ['1950', '1955', '1960', '1965', '1970 Population', 
                 '1975', '1980 Population', '1985', '1990 Population', 
                 '1995', '2000 Population', '2005', '2010 Population', 
                 '2015 Population', '2020 Population', '2023']

scaler = MinMaxScaler()

popdf_scaled = popdf.copy()
popdf[columns_scale] = scaler.fit_transform(popdf[columns_scale])

correlation_matrix = popdf_scaled[columns_scale].corr()
print(correlation_matrix)
# Out:
#                      1950      1955      1960      1965  1970 Population  \
# 1950             1.000000  0.999866  0.999460  0.998815         0.997145
# 1955             0.999866  1.000000  0.999814  0.999404         0.997982
# 1960             0.999460  0.999814  1.000000  0.999853         0.998510
# 1965             0.998815  0.999404  0.999853  1.000000         0.998949
# 1970 Population  0.997145  0.997982  0.998510  0.998949         1.000000
# 1975             0.996585  0.997690  0.998412  0.999140         0.999087
# 1980 Population  0.993858  0.995193  0.996345  0.997420         0.999195
# 1985             0.992443  0.994037  0.995587  0.996998         0.997516
# 1990 Population  0.988996  0.990784  0.992640  0.994340         0.996607
# 1995             0.986838  0.988824  0.991108  0.993100         0.994071
# 2000 Population  0.981434  0.983585  0.986363  0.988666         0.990978
# 2005             0.977371  0.979695  0.982924  0.985513         0.986791
# ...

# %% [markdown]
# ### Displaying histogram of scaled popdf

# %%
plt.figure(figsize=(5, 2))
popdf_scaled[columns_scale].hist(bins=20, edgecolor='black', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Displaying scaled popdf

# %%
print(popdf_scaled)
# Out:
#      Rank         country           Capital Continent  Area (km²)      1950  \
# 0      36     Afghanistan             Kabul      Asia      652230   7480461
# 1     138         Albania            Tirana    Europe       28748   1252582
# 2      34         Algeria           Algiers    Africa     2381741   9019866
# 3     213  American Samoa         Pago Pago   Oceania         199     19032
# 4     203         Andorra  Andorra la Vella    Europe         468      6005
# ..    ...             ...               ...       ...         ...       ...
# 211    16         Vietnam             Hanoi      Asia      331212  25109200
# 212   172  Western Sahara          El Aaiún    Africa      266000     12982
# 213    46           Yemen             Sanaa      Asia      527968   4712810
# 214    63          Zambia            Lusaka    Africa      752612   2318448
# 215    74        Zimbabwe            Harare    Africa      390757   2791326
#
# ...

# %% [markdown]
# ### Displaying Heatmap of popdf CM

# %%
plt.figure(figsize=(9, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Scaled Population Data')
plt.show()

# %% [markdown]
# ## Climate Change Indicators

# %% [markdown]
# ### Scaling Columns in Climate Change Indicators, using MinMaxScaler, correlation matrix

# %%
columns_scale1 = ['F1961', 'F1962', 'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 
                    'F1970', 'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978', 
                    'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986', 'F1987', 
                    'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994', 'F1995', 'F1996', 
                    'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002', 'F2003', 'F2004', 'F2005', 
                    'F2006', 'F2007', 'F2008', 'F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 
                    'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']

scaler = MinMaxScaler()

climdf_scaled = climdf.copy()
climdf[columns_scale1] = scaler.fit_transform(climdf[columns_scale1])


correlation_matrix1 = climdf_scaled[columns_scale1].corr()

print(correlation_matrix1)
# Out:
#           F1961     F1962     F1963     F1964     F1965     F1966     F1967  \
# F1961  1.000000 -0.329083 -0.535702  0.225209 -0.448468 -0.117961  0.733194
# F1962 -0.329083  1.000000  0.531962 -0.179892  0.324738  0.417417 -0.539587
# F1963 -0.535702  0.531962  1.000000 -0.254906  0.551574  0.147068 -0.648771
# F1964  0.225209 -0.179892 -0.254906  1.000000 -0.010730 -0.392467  0.193783
# F1965 -0.448468  0.324738  0.551574 -0.010730  1.000000  0.000901 -0.413509
# ...         ...       ...       ...       ...       ...       ...       ...
# F2018  0.329751  0.152200 -0.058505 -0.436696 -0.106528  0.345279  0.165231
# F2019  0.412572 -0.050059 -0.322618 -0.136422 -0.104356  0.320723  0.346691
# F2020  0.540589 -0.083622 -0.302464  0.064073 -0.142500  0.026835  0.456763
# F2021 -0.034898  0.309308  0.245769 -0.219027  0.141195  0.224028 -0.104885
# F2022  0.458136 -0.030936 -0.276210  0.060852 -0.289095  0.144976  0.412460
#
# ...

# %% [markdown]
# ### Displaying histogram of scaled climdf

# %%
plt.figure(figsize=(10, 6))
climdf_scaled[columns_scale1].hist(bins=20, edgecolor='black', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_4132\3954598715.py:3: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Displaying scaled climdf

# %%
print(climdf_scaled)
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# ...

# %% [markdown]
# ### Displaying heatmap of climdf CM

# %%
plt.figure(figsize=(9, 7))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Climate Change Indicators Data')
plt.show()

# %% [markdown]
# ## World GDP

# %% [markdown]
# ### Scaling Columns in World GDP, using MinMaxScaler, correlation matrix

# %%
columns_scale2 = ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', 
                    '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', 
                    '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', 
                    '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', 
                    '2020', '2021', '2022', '2023', '2024']

scaler = MinMaxScaler()

gdpdf_scaled = gdpdf.copy()
gdpdf[columns_scale2] = scaler.fit_transform(gdpdf[columns_scale2])
correlation_matrix2 = gdpdf_scaled[columns_scale2].corr()
print(correlation_matrix2)
# Out:
#           1980      1981      1982      1983      1984      1985      1986  \
# 1980  1.000000  0.441709  0.072022  0.032232  0.193358  0.082768  0.204978
# 1981  0.441709  1.000000  0.203187  0.096855  0.292938  0.144317  0.240114
# 1982  0.072022  0.203187  1.000000  0.316294 -0.141666  0.120311  0.084917
# 1983  0.032232  0.096855  0.316294  1.000000  0.390425  0.400840  0.073012
# 1984  0.193358  0.292938 -0.141666  0.390425  1.000000  0.378308  0.179367
# 1985  0.082768  0.144317  0.120311  0.400840  0.378308  1.000000  0.053359
# 1986  0.204978  0.240114  0.084917  0.073012  0.179367  0.053359  1.000000
# 1987  0.166465  0.252166 -0.033585  0.329748  0.267251  0.124396  0.328298
# 1988  0.143357  0.049673  0.284498 -0.035670 -0.190381 -0.002891  0.274837
# 1989  0.013441  0.014467  0.261491 -0.044586 -0.210118 -0.179222  0.094028
# 1990 -0.023439  0.180592  0.260058  0.009821 -0.086252  0.060903 -0.064381
# ...

# %% [markdown]
# ### Displaying histogram of scaled gdpdf

# %%
plt.figure(figsize = (10, 6))
gdpdf_scaled[columns_scale2].hist(bins=20, edgecolor='black', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Displaying scaled gdpdf

# %%
print(gdpdf_scaled)
# Out:
#            country_name                      indicator_name  1980  1981  1982  \
# 0           Afghanistan  Annual GDP growth (percent change)   NaN   NaN   NaN
# 1               Albania  Annual GDP growth (percent change)   2.7   5.7   2.9
# 2               Algeria  Annual GDP growth (percent change)  -5.4   3.0   6.4
# 3               Andorra  Annual GDP growth (percent change)   NaN   NaN   NaN
# 4                Angola  Annual GDP growth (percent change)   2.4  -4.4   0.0
# ..                  ...                                 ...   ...   ...   ...
# 191             Vietnam  Annual GDP growth (percent change)  -3.5   5.8   8.2
# 192  West Bank and Gaza  Annual GDP growth (percent change)   NaN   NaN   NaN
# 193               Yemen  Annual GDP growth (percent change)   NaN   NaN   NaN
# 194              Zambia  Annual GDP growth (percent change)   3.9   6.6  -2.9
# 195            Zimbabwe  Annual GDP growth (percent change)   NaN   NaN   NaN
#
# ...

# %% [markdown]
# ### Displaying heatmap of gdpdf CM

# %%
plt.figure(figsize=(9, 7))
sns.heatmap(correlation_matrix2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of World GDP Data')
plt.show()
